# %%
import matplotlib.pyplot as plt
import numpy as np
import random

numbers = np.random.randint(10,60,(50))

print(numbers)
# Out:
# [43 22 56 55 41 14 53 17 47 23 22 10 32 20 44 39 11 50 34 15 28 34 17 32
#  44 39 43 29 58 25 18 40 52 24 10 23 46 21 42 39 37 28 30 48 56 21 40 46
#  10 31]

# %%
x = [32, 28, 18, 46, 17, 39, 37, 39, 38, 30, 25, 29, 16, 16, 19, 20, 59, 14, 22, 46, 26, 30, 21, 30, 26, 
     45, 52, 55, 25, 38, 44, 56, 59, 20, 58, 41, 54, 45, 43, 12, 52, 14, 13, 56, 15, 36, 46, 51, 20, 36]
l=[5,10,15,20,25,30,35,40,45,50,55,60]
plt.xlabel("Age")
plt.ylabel("Population")
plt.title("Histogram")

plt.hist(x, color="g", edgecolor="r", bins=l)
plt.show()

# %%
x = [32, 28, 18, 46, 17, 39, 37, 39, 38, 30, 25, 29, 16, 16, 19, 20, 59, 14, 22, 46, 26, 30, 21, 30, 26, 
     45, 52, 55, 25, 38, 44, 56, 59, 20, 58, 41, 54, 45, 43, 12, 52, 14, 13, 56, 15, 36, 46, 51, 20, 36]
l=[5,10,15,20,25,30,35,40,45,50,55,60]
plt.xlabel("Age")
plt.ylabel("Population")
plt.title("Histogram")

plt.hist(x, color="g", edgecolor="r", bins=l, orientation="horizontal")
plt.show()

# %%
x = [32, 28, 18, 46, 17, 39, 37, 39, 38, 30, 25, 29, 16, 16, 19, 20, 59, 14, 22, 46, 26, 30, 21, 30, 26, 
     45, 52, 55, 25, 38, 44, 56, 59, 20, 58, 41, 54, 45, 43, 12, 52, 14, 13, 56, 15, 36, 46, 51, 20, 36]
l=[5,10,15,20,25,30,35,40,45,50,55,60]
plt.xlabel("Age")
plt.ylabel("Population")
plt.title("Histogram")

plt.hist(x, color="g", edgecolor="r", bins=l, cumulative=-1)
plt.show()

# %%
x = [32, 28, 18, 46, 17, 39, 37, 39, 38, 30, 25, 29, 16, 16, 19, 20, 59, 14, 22, 46, 26, 30, 21, 30, 26, 
     45, 52, 55, 25, 38, 44, 56, 59, 20, 58, 41, 54, 45, 43, 12, 52, 14, 13, 56, 15, 36, 46, 51, 20, 36]
l=[5,10,15,20,25,30,35,40,45,50,55,60]
plt.xlabel("Age")
plt.ylabel("Population")
plt.title("Histogram")

plt.hist(x, color="g", edgecolor="r", bins=l, histtype="step")
plt.show()
